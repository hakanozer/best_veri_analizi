# %% [markdown]
# # Giriş
# Bu not defteri veri analizine giriş içindir.

# %%
# Her dosyada:
import pandas as pd
import numpy as np

print(pd.__version__)  # 2.1.x
# Out:
# 3.0.2

# %%
# Series oluşturma
fiyatlar = pd.Series([150.0, 250.0, 80.0, 320.0, 95.0],
                     index=["Laptop Çantası", "Klavye", "Mouse Pad", "Kulaklık", "USB Hub"],
                     name="Fiyat (TL)")

print(fiyatlar)
print(f"\nOrtalama: {fiyatlar.mean():.2f} TL")
print(f"Maksimum: {fiyatlar.idxmax()} — {fiyatlar.max():.2f} TL")

# Koşullu erişim
pahali = fiyatlar[fiyatlar > 200]
print(f"\n200 TL üzeri:\n{pahali}")
# Out:
# Laptop Çantası    150.0
# Klavye            250.0
# Mouse Pad          80.0
# Kulaklık          320.0
# USB Hub            95.0
# Name: Fiyat (TL), dtype: float64
#
# Ortalama: 179.00 TL
# Maksimum: Kulaklık — 320.00 TL
#
# 200 TL üzeri:
# Klavye      250.0
# Kulaklık    320.0
# Name: Fiyat (TL), dtype: float64
